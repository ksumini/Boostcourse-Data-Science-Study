# %%
# !move "도로교통공단_사망 교통사고 정보_20211231.csv" .
# Out:
#         1개 파일을 이동했습니다.

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 782D-5CD7
#
#  C:\Users\sumin\OneDrive - kw.ac.kr\바탕 화면\스터디\데이터사이언스(코칭스터디) 디렉터리
#
# 2022-10-28  오후 01:42    <DIR>          .
# 2022-10-28  오후 01:42    <DIR>          ..
# 2022-10-28  오후 01:30    <DIR>          .ipynb_checkpoints
# 2022-10-28  오후 01:32               588 file-path-setting.ipynb
# 2022-10-28  오후 01:30            76,709 pandas-cheat-sheet.ipynb
# 2022-10-28  오후 12:44           396,529 Pandas_Cheat_Sheet.pdf
# 2022-10-28  오후 12:43            23,769 python-for-eda.ipynb
# 2022-10-28  오후 01:42           459,343 도로교통공단_사망 교통사고 정보_20211231.csv
# 2022-10-24  오후 06:52         5,738,391 부스터_코칭스터디 8기 Data Science OT.pptx.pdf
#                6개 파일           6,695,329 바이트
#                3개 디렉터리  74,345,795,584 바이트 남음

# %%
import pandas as pd

# %%
# ()안에서 shift + tab 키를 누르시면 도움말을 보실 수 있습니다.
pd.read_csv('./data/도로교통공단_사망 교통사고 정보_20211231.csv', encoding='cp949')
# Out:
#        발생년            발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 0     2021  2021-01-01 03:00  야  금     1     3     0     3       0    경북  ...
# 1     2021  2021-01-01 09:00  주  금     1     0     0     0       0    충남  ...
# 2     2021  2021-01-01 15:00  주  금     1     0     0     0       0    강원  ...
# 3     2021  2021-01-01 19:00  야  금     1     0     0     0       0    전남  ...
# 4     2021  2021-01-01 21:00  야  금     1     0     0     0       0    경기  ...
# ...    ...               ... .. ..   ...   ...   ...   ...     ...   ...  ...
# 2811  2021  2021-12-31 16:00  주  금     1     0     0     0       0    경북  ...
# 2812  2021  2021-12-31 17:00  주  금     1     0     0     0       0    제주  ...
# 2813  2021  2021-12-31 18:00  야  금     1     0     0     0       0    강원  ...
# 2814  2021  2021-12-31 19:00  야  금     1     0     0     0       0    경북  ...
# 2815  2021  2021-12-31 21:00  야  금     1     0     0     0       0    강원  ...
#
# ...

# %%
# 주피터 노트북이 있는 폴더의 경로를 출력합니다.
# !cd
# Out:
# C:\Users\sumin\OneDrive - kw.ac.kr\바탕 화면\스터디\데이터사이언스(코칭스터디)
